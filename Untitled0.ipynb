# %%
from google.colab import drive
import numpy as np
import os
drive.mount("/content/drive")

# Change path to yours... 
path="/content/drive/My Drive/Colab Notebooks/Molecular Interaction/CSGNN-master"
os.chdir(path) #os.chdir() 方法用于改变当前工作目录到指定的路径。
os.listdir(path) #os.listdir() 方法用于返回指定的文件夹包含的文件或文件夹的名字的列表。
# Out:
# Mounted at /content/drive
# ['utils.py',
#  'overview.jpg',
#  'README.md',
#  'instantiation.py',
#  'data',
#  '__pycache__',
#  'main.py',
#  'result.gdoc',
#  'train.py',
#  'data_preprocess.py',
#  'parms_setting.py',
#  'rewritten_loop.py',
#  'layer.py',
#  'rewritten_GCN.py',
#  'result.txt',
#  'Untitled0.ipynb']

# %%
# !pip install GraphRicciCurvature
# !pip install --no-index torch-scatter -f https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
# !pip install --no-index torch-sparse -f https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
# !pip install --no-index torch-cluster -f https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
# !pip install --no-index torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html

# !pip install torch-geometric
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 664 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 42.7 MB/s
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
# ...
#      |████████████████████████████████| 7.9 MB 4.3 MB/s
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
# ...
#      |████████████████████████████████| 3.5 MB 3.7 MB/s
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
# ...
#      |████████████████████████████████| 2.4 MB 3.7 MB/s
# ...
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.0+cu113.html
# ...
#      |████████████████████████████████| 709 kB 4.2 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 467 kB 4.3 MB/s
# ...

# %%
# !python main.py
# Out:
# The code uses GPU...
# Loading DDI seed0 dataset...
# Graph with 1514 nodes and 48514 edges
# INFO:GraphRicciCurvature:Edge weight not detected in graph, use "weight" as default edge weight.
# INFO:GraphRicciCurvature:Self-loop edge detected. Removing 1514 self-loop edges.
# INFO:GraphRicciCurvature:85.657806 secs for Ricci curvature computation.
# positve examples: 48514, negative examples: 48514.
# Extracting features...
# /content/drive/MyDrive/Colab Notebooks/Molecular Interaction/CSGNN-master/utils.py:12: RuntimeWarning: divide by zero encountered in power
#   r_inv = np.power(rowsum, -1).flatten()
# Loading finished!
# Start Training...
# -------- Epoch 1 --------
# epoch: 1/ iteration: 1/ loss_train: 0.6998552
# epoch: 1/ iteration: 101/ loss_train: 0.4816215
# epoch: 1/ iteration: 201/ loss_train: 0.4812271
# epoch: 1/ iteration: 301/ loss_train: 0.3846424
# epoch: 1/ iteration: 401/ loss_train: 0.48414445
# epoch: 1/ iteration: 501/ loss_train: 0.36049622
# ...
